# %% [markdown]
# Тестовое задание:
#
# Цель: разработать скрипт для сбора и обработки данных с использованием API Binance и прогнозирования временных рядов с помощью LSTM-модели.
#
# Этапы выполнения задания:
#
# 1. Изучить документацию RESTful API Binance (https://binance-docs.github.io/apidocs/spot/en/) и написать скрипт на Python с использованием библиотеки Requests, чтобы получить данные о котировках криптовалют. Сохранить полученные данные в формате CSV.
#
# 2. Загрузить полученный CSV-файл с данными в Python с использованием библиотеки Pandas и выполнить предварительную обработку данных (например, удаление пропусков, преобразование даты и времени, масштабирование).
#
# 3. С использованием библиотеки NumPy, разделить данные на обучающую и тестовую выборки.
#
# 4. Создать и обучить LSTM-модель с использованием библиотеки Keras или TensorFlow на основе подготовленных данных. Подобрать архитектуру и гиперпараметры модели, чтобы достичь наилучшего качества прогнозирования.
#
# 5. Оценить качество модели на тестовой выборке, используя подходящие метрики, такие как среднеквадратичная ошибка (MSE) или средняя абсолютная ошибка (MAE).
#
# 6. Визуализировать предсказания модели для тестовой выборки на графике с помощью библиотеки Matplotlib или Plotly. Вывести график с предсказанием на час вперед от последних полученных данных.

# %%
import requests
from datetime import datetime
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import tensorflow as tf

# %%
api_key = ''
api_secret = ''
# задаем список торговых пар
symbols = ['BTCUSDT', 'ETHUSDT', 'BNBUSDT', 'XRPUSDT', 'LTCUSDT']
interval = '1d'
limit = 1000

for symbol in symbols:
    url = f'https://api.binance.com/api/v3/klines?symbol={symbol}&interval={interval}&limit={limit}'
    response = requests.get(url, headers={'X-MBX-APIKEY': api_key})

    if response.status_code == 200:
        info = response.json()
        data = pd.DataFrame(info)
        df = pd.DataFrame()
        df['date'] = data.iloc[:,0]
        df['date'] = pd.to_datetime(df['date'], unit='ms')
        df['open'] = data.iloc[:,1].astype(float)
        df['high'] = data.iloc[:,2].astype(float)
        df['low'] = data.iloc[:,3].astype(float)
        df['close'] = data.iloc[:,4].astype(float)
        df['volume_coin'] = data.iloc[:,5].astype(float)
        df['volume_usd'] = data.iloc[:,7].astype(float)
        df['trades'] = data.iloc[:,8].astype(float)
        df.to_csv(f'binance_quotes_{symbol}.csv', index=False)
        print(f'Данные сохранены по {symbol}')
    else:
        print(f"Ошибка запроса по {symbol}. HTTP статус: {response.status_code}")
# Out:
# Данные сохранены по BTCUSDT
# Данные сохранены по ETHUSDT
# Данные сохранены по BNBUSDT
# Данные сохранены по XRPUSDT
# Данные сохранены по LTCUSDT

# %%
# прочитаем полученные данные
df_btc = pd.read_csv('binance_quotes_BTCUSDT.csv')
# df_eth = pd.read_csv('binance_quotes_ETHUSDT.csv')
# df_bnb = pd.read_csv('binance_quotes_BNBUSDT.csv')
# df_ltc = pd.read_csv('binance_quotes_LTCUSDT.csv')
# df_xrp = pd.read_csv('binance_quotes_XRPUSDT.csv')

# %% [markdown]
# Посторим графики цены, для каждой монеты

# %%
# BTC

plt.figure(figsize=(16,6))
plt.plot(df_btc['open'], color="blue")
# plt.plot(df_btc['high'])
# plt.plot(df_btc['low'])
# plt.plot(df_btc['close'], color='red')
plt.title('График цены BTC')
plt.ylabel('Цена')
plt.xlabel('Количество часов')
plt.legend(['open', 'close'], loc='upper left')
plt.show()

# %%
# # ETH
#
# plt.figure(figsize=(16,6))
# plt.plot(df_eth['open'], color='blue')
# # plt.plot(df_eth['high'])
# # plt.plot(df_eth['low'])
# # plt.plot(df_eth['close'])
# plt.title(f'График цены ETH')
# plt.ylabel('Цена')
# plt.xlabel('Количество дней')
# plt.legend(['open', 'close'], loc='upper left')
# plt.show()

# %%
# # BNB
#
# plt.figure(figsize=(16,6))
# plt.plot(df_bnb['open'], color='blue')
# # plt.plot(df_bnb['high'])
# # plt.plot(df_bnb['low'])
# # plt.plot(df_bnb['close'])
# plt.title(f'График цены BNB')
# plt.ylabel('Цена')
# plt.xlabel('Количество дней')
# plt.legend(['open', 'close'], loc='upper left')
# plt.show()

# %%
# # LTC
#
# plt.figure(figsize=(16,6))
# plt.plot(df_ltc['open'], color='blue')
# # plt.plot(df_ltc['high'])
# # plt.plot(df_ltc['low'])
# # plt.plot(df_ltc['close'])
# plt.title(f'График цены LTC')
# plt.ylabel('Цена')
# plt.xlabel('Количество дней')
# plt.legend(['open', 'close'], loc='upper left')
# plt.show()

# %%
# # XRP
# plt.figure(figsize=(16,6))
# plt.plot(df_xrp['open'], color='blue')
# # plt.plot(df_xrp['high'])
# # plt.plot(df_xrp['low'])
# # plt.plot(df_xrp['close'])
# plt.title(f'График цены XRP')
# plt.ylabel('Цена')
# plt.xlabel('Количество дней')
# plt.legend(['open', 'close'], loc='upper left')
# plt.show()

# %% [markdown]
# Проверим, влияли ли количество объема, на изменение цены

# %%
# BTC
sns.scatterplot(data=df_btc, x='date', y='close', hue='volume_usd')
# Out:
# <Axes: xlabel='date', ylabel='close'>

# %%
# ETH
# sns.scatterplot(data=df_eth, x='date', y='close', hue='volume_usd')

# %%
# BNB
# sns.scatterplot(data=df_bnb, x='date', y='close',hue='volume_usd')

# %%
# LTC
# sns.scatterplot(data=df_ltc, x='date', y='close', hue='volume_usd')

# %%
# XRP
# sns.scatterplot(data=df_xrp, x='date', y='close', hue='volume_usd')

# %% [markdown]
# Дальнейшая работа будет проводиться с данными по BTC

# %% [markdown]
# Разделение на тренировочный и тестовый. Нормализация данных

# %%
df_btc
# Out:
#            date      open      high       low     close   volume_coin  \
# 0    2020-07-16   9197.60   9226.15   9047.25   9133.72  43375.571191
# 1    2020-07-17   9133.72   9186.83   9089.81   9154.32  28054.358741
# 2    2020-07-18   9154.31   9219.30   9121.10   9170.28  22554.541457
# 3    2020-07-19   9170.30   9232.27   9101.35   9208.99  26052.019417
# 4    2020-07-20   9208.99   9221.52   9131.00   9160.78  35458.764082
# ..          ...       ...       ...       ...       ...           ...
# 995  2023-04-07  28033.83  28100.00  27766.94  27906.33  24762.093870
# 996  2023-04-08  27906.34  28154.99  27859.02  27938.38  19479.967350
# 997  2023-04-09  27938.38  28530.00  27800.00  28323.76  32531.161010
# 998  2023-04-10  28323.76  29770.00  28170.00  29637.34  67754.062200
# 999  2023-04-11  29637.35  30430.00  29590.00  30209.81  54896.959070
#
#        volume_usd     trades
# 0    3.958837e+08   681807.0
# 1    2.563603e+08   470991.0
# 2    2.066281e+08   430377.0
# 3    2.385220e+08   440449.0
# 4    3.252973e+08   557096.0
# ..            ...        ...
# 995  6.913237e+08   655634.0
# 996  5.453245e+08   624159.0
# 997  9.139159e+08   777589.0
# 998  1.955301e+09  1285695.0
# 999  1.650420e+09  1074362.0
#
# [1000 rows x 8 columns]

# %%
num_shape = 800

# возьмём цену открытия
train = df_btc.iloc[:num_shape, 1:2].values
test = df_btc.iloc[num_shape:, 1:2].values

train.shape, test.shape
# Out:
# ((800, 1), (200, 1))

# %%
scaler = MinMaxScaler(feature_range = (0, 1))

train_scaled = scaler.fit_transform(train)
test_scaled = scaler.fit_transform(test)

# %%
X_train = []
y_train = []

time_step = 60

for i in range(time_step, num_shape):
    X_train_ = np.reshape(train_scaled[i - time_step:i, 0], (time_step, 1))
    X_train.append(X_train_)
    y_train.append(train_scaled[i, 0])
X_train = np.stack(X_train)
y_train = np.stack(y_train)

# %% [markdown]
# Создаём модель

# %%
epochs = 100
batch = 32
lr = 0.0001
adam = tf.keras.optimizers.Adam(lr)

# %%
model_lstm = tf.keras.Sequential([
    tf.keras.layers.LSTM(256, input_shape=(X_train.shape[1], 1), return_sequences=True),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.LSTM(192, return_sequences=True),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.LSTM(128, return_sequences=True),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1)
])

model_lstm.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 256)           264192
#
#  dropout (Dropout)           (None, 60, 256)           0
#
#  lstm_1 (LSTM)               (None, 60, 192)           344832
#
#  dropout_1 (Dropout)         (None, 60, 192)           0
#
#  lstm_2 (LSTM)               (None, 60, 128)           164352
#
#  dropout_2 (Dropout)         (None, 60, 128)           0
#
#  lstm_3 (LSTM)               (None, 64)                49408
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 822,849
# Trainable params: 822,849
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_lstm.compile(optimizer=adam, loss='mean_squared_error')

# %%
# callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_loss", min_delta=0.01, patience=10, verbose=1)]

# %%
history = model_lstm.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 12s 19ms/step - loss: 0.0919
# Epoch 2/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0187
# Epoch 3/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0158
# Epoch 4/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0141
# Epoch 5/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0132
# Epoch 6/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0117
# Epoch 7/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0114
# Epoch 8/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0121
# Epoch 9/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0114
# Epoch 10/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0115
# Epoch 11/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0113
# Epoch 12/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0090
# Epoch 13/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0097
# Epoch 14/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0098
# Epoch 15/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0101
# Epoch 16/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0100
# Epoch 17/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0099
# Epoch 18/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0103
# Epoch 19/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0094
# Epoch 20/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0086
# Epoch 21/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 22/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0085
# Epoch 23/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0084
# Epoch 24/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0079
# Epoch 25/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0087
# Epoch 26/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0096
# Epoch 27/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0091
# Epoch 28/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0085
# Epoch 29/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 30/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0092
# Epoch 31/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0088
# Epoch 32/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0085
# Epoch 33/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0073
# Epoch 34/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0076
# Epoch 35/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0082
# Epoch 36/100
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0081
# Epoch 37/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0082
# Epoch 38/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0087
# Epoch 39/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 40/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0086
# Epoch 41/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0077
# Epoch 42/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0074
# Epoch 43/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0081
# Epoch 44/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 45/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0075
# Epoch 46/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 47/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0080
# Epoch 48/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 49/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0070
# Epoch 50/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 51/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0075
# Epoch 52/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0081
# Epoch 53/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0066
# Epoch 54/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0072
# Epoch 55/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0073
# Epoch 56/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0072
# Epoch 57/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 58/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0070
# Epoch 59/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0070
# Epoch 60/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0071
# Epoch 61/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0062
# Epoch 62/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0070
# Epoch 63/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 64/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 65/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 66/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 67/100
# 24/24 [==============================] - 0s 15ms/step - loss: 0.0067
# Epoch 68/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0060
# Epoch 69/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0059
# Epoch 70/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0059
# Epoch 71/100
# 24/24 [==============================] - 0s 18ms/step - loss: 0.0060
# Epoch 72/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0062
# Epoch 73/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0058
# Epoch 74/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 75/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 76/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 77/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 78/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 79/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 80/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 81/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 82/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0058
# Epoch 83/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 84/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 85/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0057
# Epoch 86/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 87/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 88/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 89/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 90/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0052
# Epoch 91/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 92/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 93/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0054
# Epoch 94/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 95/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 96/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 97/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0053
# Epoch 98/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0056
# Epoch 99/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0055
# Epoch 100/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.0048

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# Предсказание

# %%
df_volume = np.vstack((train, test))

# %%
inputs = df_volume[df_volume.shape[0] - test.shape[0] - time_step:]
inputs = inputs.reshape(-1, 1)
inputs = scaler.transform(inputs)

inputs.shape
# Out:
# (260, 1)

# %%
num_2 = df_volume.shape[0] - num_shape + time_step

X_test = []

for i in range(time_step, num_2):
    X_test_ = np.reshape(inputs[i - time_step:i, 0], (time_step, 1))
    X_test.append(X_test_)

# %%
X_test = np.stack(X_test)

# %%
predict = model_lstm.predict(X_test)
predict = scaler.inverse_transform(predict)
# Out:
# 7/7 [==============================] - 1s 10ms/step

# %%
predict.shape
# Out:
# (200, 1)

# %%
test_rmse = np.sqrt(mean_squared_error(test, predict))

# %%
test_rmse
# Out:
# 1356.7002908039533

# %% [markdown]
# Получается, ошибка примерно в 1400$

# %%
plt.figure(figsize=(20,7))
plt.plot(df_btc['date'].values[800:], df_volume[800:], color = 'red', label = 'Цена BTC ')
plt.plot(df_btc['date'][-predict.shape[0]:].values, predict, color = 'blue', label = 'Цена предсказанная моделью')
plt.xticks(np.arange(100, df_btc[800:].shape[0], 200))
plt.title('Предсказание цены BTC')
plt.xlabel('Дата')
plt.ylabel('Цена ($)')
plt.legend()
plt.show()

# %% [markdown]
# Предсказание на 5 дней

# %%
pred_ = predict[-1].copy()
prediction_full = []
df_copy = df_btc.iloc[:, 1:2][1:].values

for j in range(5):
    df_ = np.vstack((df_copy, pred_))
    train_ = df_[:num_shape]
    test_ = df_[num_shape:]
    
    df_volume_ = np.vstack((train_, test_))

    inputs_ = df_volume_[df_volume_.shape[0] - test_.shape[0] - time_step:]
    inputs_ = inputs_.reshape(-1,1)
    inputs_ = scaler.transform(inputs_)

    X_test_2 = []

    for k in range(time_step, num_2):
        X_test_3 = np.reshape(inputs_[k-time_step:k, 0], (time_step, 1))
        X_test_2.append(X_test_3)

    X_test_ = np.stack(X_test_2)
    predict_ = model_lstm.predict(X_test_)
    pred_ = scaler.inverse_transform(predict_)
    prediction_full.append(pred_[-1][0])
    df_copy = df_[j:]
# Out:
# 7/7 [==============================] - 0s 10ms/step
# 7/7 [==============================] - 0s 10ms/step
# 7/7 [==============================] - 0s 10ms/step
# 7/7 [==============================] - 0s 9ms/step
# 7/7 [==============================] - 0s 9ms/step

# %%
prediction_full_new = np.vstack((predict, np.array(prediction_full).reshape(-1, 1)))

# %%
prediction_full_new
# Out:
# array([[19477.877],
#        [19177.729],
#        [18941.611],
#        [18777.754],
#        [18690.338],
#        [18673.74 ],
#        [18720.865],
#        [18822.848],
#        [18963.227],
#        [19119.418],
#        [19264.379],
#        [19385.883],
#        [19492.924],
#        [19594.463],
#        [19691.957],
#        [19773.953],
#        [19825.246],
#        [19836.71 ],
#        [19801.34 ],
#        [19719.3  ],
#        [19600.445],
#        [19464.504],
#        [19329.387],
#        [19207.836],
#        [19111.516],
#        [19053.035],
#        [19035.178],
#        [19050.86 ],
#        [19086.283],
#        [19129.34 ],
#        [19171.572],
#        [19213.953],
#        [19255.553],
#        [19307.242],
#        [19391.824],
#        [19515.89 ],
#        [19678.266],
#        [19871.973],
#        [20080.152],
#        [20279.057],
#        [20446.434],
#        [20560.717],
#        [20611.242],
#        [20616.797],
#        [20607.002],
#        [20601.088],
#        [20602.607],
#        [20570.625],
#        [20420.408],
#        [20126.652],
#        [19701.19 ],
#        [19180.137],
#        [18607.96 ],
#        [18035.963],
#        [17516.322],
#        [17087.018],
#        [16769.977],
#        [16571.54 ],
#        [16483.562],
#        [16480.785],
#        [16523.744],
#        [16580.281],
#        [16633.707],
#        [16676.625],
#        [16705.469],
#        [16717.873],
#        [16712.883],
#        [16687.74 ],
#        [16644.834],
#        [16600.387],
#        [16568.666],
#        [16560.154],
#        [16575.531],
#        [16612.46 ],
#        [16663.75 ],
#        [16722.16 ],
#        [16777.213],
#        [16825.664],
#        [16866.207],
#        [16898.879],
#        [16923.752],
#        [16943.246],
#        [16969.002],
#        [17012.598],
#        [17073.137],
#        [17131.564],
#        [17169.43 ],
#        [17174.908],
#        [17140.398],
#        [17073.266],
#        [16987.025],
#        [16896.69 ],
#        [16814.531],
#        [16750.277],
#        [16709.223],
#        [16693.55 ],
#        [16699.05 ],
#        [16715.785],
#        [16734.701],
#        [16748.918],
#        [16753.467],
#        [16747.254],
#        [16732.861],
#        [16714.393],
#        [16698.197],
#        [16689.488],
#        [16692.86 ],
#        [16709.72 ],
#        [16741.52 ],
#        [16789.033],
#        [16853.072],
#        [16940.6  ],
#        [17069.738],
#        [17270.48 ],
#        [17577.588],
#        [18002.682],
#        [18533.135],
#        [19129.55 ],
#        [19726.67 ],
#        [20264.99 ],
#        [20731.705],
#        [21133.357],
#        [21477.441],
#        [21772.293],
#        [22016.48 ],
#        [22214.852],
#        [22372.066],
#        [22494.016],
#        [22585.734],
#        [22667.555],
#        [22738.693],
#        [22799.588],
#        [22863.91 ],
#        [22939.348],
#        [23026.428],
#        [23118.822],
#        [23199.514],
#        [23250.217],
#        [23270.523],
#        [23262.709],
#        [23208.477],
#        [23092.504],
#        [22918.947],
#        [22704.41 ],
#        [22472.922],
#        [22258.336],
#        [22132.709],
#        [22136.746],
#        [22299.668],
#        [22620.008],
#        [23054.125],
#        [23547.86 ],
#        [24030.988],
#        [24432.64 ],
#        [24697.264],
#        [24783.082],
#        [24683.559],
#        [24434.979],
#        [24093.668],
#        [23713.807],
#        [23354.611],
#        [23060.842],
#        [22836.656],
#        [22671.176],
#        [22551.998],
#        [22468.293],
#        [22407.984],
#        [22351.975],
#        [22259.543],
#        [22098.748],
#        [21866.758],
#        [21611.271],
#        [21429.318],
#        [21415.42 ],
#        [21614.6  ],
#        [22032.69 ],
#        [22684.518],
#        [23530.633],
#        [24508.578],
#        [25515.975],
#        [26446.746],
#        [27183.947],
#        [27677.21 ],
#        [27901.707],
#        [27874.682],
#        [27661.043],
#        [27321.744],
#        [26925.   ],
#        [26562.309],
#        [26301.607],
#        [26192.453],
#        [26252.623],
#        [26459.748],
#        [26756.701],
#        [27088.006],
#        [27404.596],
#        [27666.076],
#        [27844.82 ],
#        [27932.041],
#        [27944.938],
#        [27944.049],
#        [27944.049],
#        [27936.953],
#        [27062.303],
#        [23184.135]], dtype=float32)

# %%
df_date = df_btc[['date']]

for h in range(5):
    df_date_add = pd.to_datetime(df_date['date'].iloc[-1]) + pd.DateOffset(days=1)
    df_date_add = pd.DataFrame([df_date_add.strftime("%Y-%m-%d")], columns=['date'])
    df_date = df_date.append(df_date_add)
df_date = df_date.reset_index(drop=True)
# Out:
# <ipython-input-39-2b6ebf15550d>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_date = df_date.append(df_date_add)
# <ipython-input-39-2b6ebf15550d>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_date = df_date.append(df_date_add)
# <ipython-input-39-2b6ebf15550d>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_date = df_date.append(df_date_add)
# <ipython-input-39-2b6ebf15550d>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_date = df_date.append(df_date_add)
# <ipython-input-39-2b6ebf15550d>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_date = df_date.append(df_date_add)

# %%
plt.figure(figsize=(20,7))
plt.plot(df_btc['date'].values[800:], df_volume[800:], color = 'red', label = 'Цена BTC')
plt.plot(df_date['date'][-prediction_full_new.shape[0]:].values, prediction_full_new, color = 'blue', label = 'Цена предсказанная моделью')
plt.xticks(np.arange(100,df_btc[800:].shape[0],200))
plt.title('Предсказание цены BTC')
plt.xlabel('Дата')
plt.ylabel('Цена ($)')
plt.legend()
plt.show()
